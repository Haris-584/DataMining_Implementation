# %% [markdown]
# ## Beef Dataset

# %%
from scipy.io import arff
import pandas as pd

beefdata = arff.loadarff("./data/Beef_TRAIN.arff")
beef = pd.DataFrame(beefdata[0])
beef.head()
# Out:
#        att1      att2      att3      att4      att5      att6      att7  \
# 0 -0.362922 -0.365328 -0.387812 -0.405590 -0.399002 -0.366583 -0.324542
# 1 -0.116280 -0.116428 -0.105431 -0.089785 -0.065172 -0.050817 -0.039526
# 2 -0.179317 -0.181082 -0.178096 -0.170047 -0.157453 -0.147430 -0.132370
# 3 -0.103757 -0.095310 -0.080262 -0.068881 -0.051380 -0.038431 -0.023409
# 4 -0.208100 -0.196968 -0.177934 -0.154312 -0.121045 -0.105240 -0.079494
#
#        att8      att9     att10  ...    att462    att463    att464    att465  \
# 0 -0.317327 -0.326529 -0.304882  ... -1.849287 -1.849392 -1.876268 -1.880451
# 1 -0.026389 -0.022588 -0.013289  ... -0.015909 -0.023473 -0.031260 -0.032699
# 2 -0.122529 -0.116479 -0.104327  ... -0.978762 -0.981852 -0.981151 -0.987072
# 3 -0.010586 -0.007678 -0.000419  ...  0.371429  0.371252  0.372592  0.368065
# 4 -0.041511 -0.025281 -0.009221  ... -0.931174 -0.934233 -0.946597 -0.950463
#
#      att466    att467    att468    att469    att470  target
# 0 -1.858176 -1.844686 -1.836215 -1.840084 -1.861105    b'1'
# 1 -0.037053 -0.047939 -0.058936 -0.052773 -0.057091    b'1'
# 2 -0.992421 -0.997951 -1.001223 -1.001145 -1.009013    b'1'
# 3  0.364322  0.360908  0.355496  0.356002  0.350463    b'1'
# 4 -0.952927 -0.970516 -0.979608 -0.968137 -0.980331    b'1'
#
# [5 rows x 471 columns]

# %%
beef.shape
# Out:
# (30, 471)

# %%
beef.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Columns: 471 entries, att1 to target
# dtypes: float64(470), object(1)
# memory usage: 110.5+ KB

# %%
beef.isna().any()
# Out:
# att1      False
# att2      False
# att3      False
# att4      False
# att5      False
#           ...
# att467    False
# att468    False
# att469    False
# att470    False
# target    False
# Length: 471, dtype: bool

# %%
beef.isna().sum()
# Out:
# att1      0
# att2      0
# att3      0
# att4      0
# att5      0
#          ..
# att467    0
# att468    0
# att469    0
# att470    0
# target    0
# Length: 471, dtype: int64

# %% [markdown]
# Missing Values

# %%
import seaborn as sns
sns.heatmap(beef.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %% [markdown]
# ### line plot

# %%
from pandas import read_csv
from matplotlib import pyplot
beef.plot()
pyplot.show()

# %% [markdown]
# ### Line plot with dots

# %%
from pandas import read_csv
from matplotlib import pyplot
beef.plot(style='k.')
pyplot.show()

# %% [markdown]
# ### Histogram

# %%
from pandas import read_csv
from matplotlib import pyplot
beef.hist(figsize=(12,12))
pyplot.show()

# %% [markdown]
# ### Density ploy

# %%
from pandas import read_csv
from matplotlib import pyplot
beef.plot(kind='kde')
pyplot.show()

# %% [markdown]
# end
