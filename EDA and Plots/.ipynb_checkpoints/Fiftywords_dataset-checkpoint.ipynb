# %% [markdown]
# ##  FiFty words Dataset

# %%
from scipy.io import arff
import pandas as pd
fiftydata = arff.loadarff("./data/FiftyWords_TRAIN.arff")
fiftywords = pd.DataFrame(fiftydata[0])
fiftywords.head()
# Out:
#        att1      att2      att3      att4      att5      att6      att7  \
# 0 -0.790419 -0.765171 -0.733542 -0.699633 -0.667740 -0.638633 -0.611808
# 1 -0.764061 -0.744448 -0.743794 -0.720950 -0.717986 -0.702817 -0.691825
# 2 -0.817041 -0.733105 -0.627820 -0.495715 -0.334888 -0.143279  0.077817
# 3 -1.103800 -1.071184 -1.024899 -0.967286 -0.905158 -0.844317 -0.783511
# 4 -0.435999 -0.316359 -0.211705 -0.114854 -0.019499  0.070713  0.143294
#
#        att8      att9     att10  ...    att262    att263    att264    att265  \
# 0 -0.587282 -0.564301 -0.544381  ... -0.621745 -0.654709 -0.690325 -0.727638
# 1 -0.680799 -0.671426 -0.683866  ... -0.453934 -0.365317 -0.311797 -0.336820
# 2  0.322732  0.586229  0.862018  ... -0.909609 -0.914889 -0.921817 -0.931149
# 3 -0.720846 -0.658545 -0.592222  ... -0.974656 -1.000649 -1.031489 -1.064847
# 4  0.193429  0.226835  0.251032  ... -0.163001 -0.264176 -0.348394 -0.408835
#
#      att266    att267    att268    att269    att270  target
# ...

# %%
fiftywords.shape
# Out:
# (450, 271)

# %%
fiftywords.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Columns: 271 entries, att1 to target
# dtypes: float64(270), object(1)
# memory usage: 952.9+ KB

# %%
fiftywords.isna().any()
# Out:
# att1      False
# att2      False
# att3      False
# att4      False
# att5      False
#           ...
# att267    False
# att268    False
# att269    False
# att270    False
# target    False
# Length: 271, dtype: bool

# %%
fiftywords.isna().sum()
# Out:
# att1      0
# att2      0
# att3      0
# att4      0
# att5      0
#          ..
# att267    0
# att268    0
# att269    0
# att270    0
# target    0
# Length: 271, dtype: int64

# %% [markdown]
# Missing Values

# %%
import seaborn as sns
sns.heatmap(fiftywords.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %% [markdown]
# ### line plot

# %%
fiftywords.plot()
pyplot.show()

# %% [markdown]
# ### Line plot with dots

# %%
from pandas import read_csv
from matplotlib import pyplot
fiftywords.plot(style='k.')
pyplot.show()

# %% [markdown]
# ### Histogram

# %%
from pandas import read_csv
from matplotlib import pyplot
fiftywords.hist(figsize=(12,12))
pyplot.show()

# %% [markdown]
# ### Density ploy

# %%
from pandas import read_csv
from matplotlib import pyplot
fiftywords.plot(kind='kde')
pyplot.show()
