# %% [markdown]
# ## Cricket Dataset

# %%
from scipy.io import arff
import pandas as pd

cricketdata = arff.loadarff("./data/CricketX_TRAIN.arff")
cricket = pd.DataFrame(cricketdata[0])
cricket.head()
# Out:
#        att1      att2      att3      att4      att5      att6      att7  \
# 0 -0.687540 -0.607321 -0.826569 -0.898656 -1.088473 -1.045337 -0.856318
# 1 -0.777986 -0.960542 -0.990524 -1.094866 -1.033557 -0.923433 -0.441066
# 2  0.837770  0.859279  0.904456  0.925029  0.629778  0.448387  0.422124
# 3 -0.640682 -0.506087 -0.513861 -0.659987 -0.645217 -0.719385 -0.610595
# 4  0.462862  0.615836  0.644487  0.618524  0.547334  0.530452  0.380320
#
#        att8      att9     att10  ...    att292    att293    att294    att295  \
# 0 -0.698750 -0.567828 -0.671483  ... -0.405522 -0.196937 -0.171765 -0.158688
# 1 -0.440952 -0.549592 -0.390090  ... -0.970914 -0.996568 -0.795047 -0.772004
# 2  0.378875  0.408665  0.034316  ...  0.776324  0.718626  0.702662  0.695362
# 3 -0.612379 -0.557963 -0.514956  ... -0.503563 -0.514170 -0.513744 -0.504143
# 4  0.348934  0.382738  0.316948  ...  1.074723  1.077710  0.924485  0.914788
#
#      att296    att297    att298    att299    att300  target
# ...

# %%
cricket.shape
# Out:
# (390, 301)

# %%
cricket.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Columns: 301 entries, att1 to target
# dtypes: float64(300), object(1)
# memory usage: 917.2+ KB

# %%
cricket.isna().any()
# Out:
# att1      False
# att2      False
# att3      False
# att4      False
# att5      False
#           ...
# att297    False
# att298    False
# att299    False
# att300    False
# target    False
# Length: 301, dtype: bool

# %%
cricket.isna().sum()
# Out:
# att1      0
# att2      0
# att3      0
# att4      0
# att5      0
#          ..
# att297    0
# att298    0
# att299    0
# att300    0
# target    0
# Length: 301, dtype: int64

# %% [markdown]
# Missing Values

# %%
import seaborn as sns
sns.heatmap(cricket.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %% [markdown]
# ### line plot

# %%
from pandas import read_csv
from matplotlib import pyplot
cricket.plot()
pyplot.show()

# %% [markdown]
# ### Line plot with dots

# %%
from pandas import read_csv
from matplotlib import pyplot
cricket.plot(style='k.')
pyplot.show()

# %% [markdown]
# ### Histogram

# %%
from pandas import read_csv
from matplotlib import pyplot
cricket.hist(figsize=(12,12))
pyplot.show()

# %% [markdown]
# ### Density ploy

# %%
from pandas import read_csv
from matplotlib import pyplot
cricket.plot(kind='kde')
pyplot.show()

# %% [markdown]
# end
