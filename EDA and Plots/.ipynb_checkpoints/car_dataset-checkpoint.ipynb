# %% [markdown]
# ##  Car  Dataset

# %%
from scipy.io import arff
import pandas as pd

cardata = arff.loadarff("./data/Car_TRAIN.arff")
car = pd.DataFrame(cardata[0])
car.head()
# Out:
#        att1      att2      att3      att4      att5      att6      att7  \
# 0  1.654107  1.621582  1.589211  1.557358  1.525398  1.493311  1.483532
# 1  1.750569  1.710457  1.670466  1.630688  1.616339  1.611841  1.607774
# 2  1.551691  1.517339  1.481993  1.445524  1.441751  1.426236  1.390641
# 3  1.495626  1.457534  1.431099  1.429687  1.428633  1.427785  1.393253
# 4  1.713808  1.675160  1.650911  1.646261  1.613406  1.575549  1.537942
#
#        att8      att9     att10  ...    att569    att570    att571    att572  \
# 0  1.483766  1.455129  1.423884  ...  1.672432  1.669461  1.666592  1.664132
# 1  1.619430  1.650838  1.626347  ...  1.527729  1.562123  1.596534  1.607919
# 2  1.385668  1.385117  1.384878  ...  1.315309  1.345369  1.378141  1.407747
# 3  1.357073  1.320893  1.284713  ...  1.225467  1.215470  1.248229  1.283398
# 4  1.547532  1.578335  1.612165  ...  1.441860  1.475111  1.502538  1.531247
#
#      att573    att574    att575    att576    att577  target
# 0  1.661809  1.659795  1.640838  1.607442  1.607442    b'1'
# 1  1.600977  1.626217  1.656153  1.690776  1.690776    b'4'
# 2  1.404180  1.421188  1.452594  1.486909  1.486909    b'2'
# 3  1.319464  1.355534  1.390680  1.424215  1.424215    b'1'
# 4  1.564622  1.593617  1.621924  1.655406  1.655406    b'2'
#
# [5 rows x 578 columns]

# %%
car.shape
# Out:
# (60, 578)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Columns: 578 entries, att1 to target
# dtypes: float64(577), object(1)
# memory usage: 271.1+ KB

# %%
car.isna().any()
# Out:
# att1      False
# att2      False
# att3      False
# att4      False
# att5      False
#           ...
# att574    False
# att575    False
# att576    False
# att577    False
# target    False
# Length: 578, dtype: bool

# %%
car.isna().sum()
# Out:
# att1      0
# att2      0
# att3      0
# att4      0
# att5      0
#          ..
# att574    0
# att575    0
# att576    0
# att577    0
# target    0
# Length: 578, dtype: int64

# %% [markdown]
# Missing Values

# %%
import seaborn as sns
sns.heatmap(car.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %% [markdown]
# ### line plot

# %%
from pandas import read_csv
from matplotlib import pyplot
car.plot()
pyplot.show()

# %% [markdown]
# ### Line plot with dots

# %%
from pandas import read_csv
from matplotlib import pyplot
car.plot(style='k.')
pyplot.show()

# %% [markdown]
# ### Histogram

# %%
from pandas import read_csv
from matplotlib import pyplot
car.hist(figsize=(12,12))
pyplot.show()

# %% [markdown]
# ### Density ploy

# %%
from pandas import read_csv
from matplotlib import pyplot
car.plot(kind='kde')
pyplot.show()

# %% [markdown]
# end
