# %% [markdown]
# ## 1. CBF Dataset

# %%
from scipy.io import arff
import pandas as pd

cbfData = arff.loadarff("./data/CBF_TRAIN.arff")
cbf = pd.DataFrame(cbfData[0])

cbf.head()
# Out:
#        att1      att2      att3      att4      att5      att6      att7  \
# 0 -0.464276 -0.555048 -0.842843 -0.865895 -0.936396 -0.817270 -0.263612
# 1 -0.896972 -0.685686 -1.351382 -1.458667 -1.165346 -1.403929 -1.821800
# 2 -0.464696 -0.567739 -0.032023 -0.635046 -0.602826 -0.266856 -0.267061
# 3 -0.187190 -0.620808 -0.815661 -0.521398 -0.790423 -0.967517 -1.487006
# 4 -1.136017 -1.319195 -1.844624 -0.788692 -0.251715 -1.487603 -0.668764
#
#        att8      att9     att10  ...    att120    att121    att122    att123  \
# 0 -1.258048 -1.250393 -0.918308  ... -1.083700 -1.017961 -0.916029 -1.134289
# 1 -0.831601 -1.016312 -0.803530  ... -1.568676 -1.364040 -1.155177 -0.995861
# 2 -0.931042 -0.449382 -0.721342  ... -0.637158 -0.155260 -0.688129 -0.885609
# 3 -0.277887 -0.835075  0.050591  ... -0.726286  0.183778 -0.737444 -1.113997
# 4 -0.340360 -1.046382 -0.312214  ... -1.073514 -1.611362 -1.064340 -0.970736
#
#      att124    att125    att126    att127    att128  target
# ...

# %%
cbf.shape
# Out:
# (30, 129)

# %%
cbf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Columns: 129 entries, att1 to target
# dtypes: float64(128), object(1)
# memory usage: 30.4+ KB

# %%
cbf.isna().any()
# Out:
# att1      False
# att2      False
# att3      False
# att4      False
# att5      False
#           ...
# att125    False
# att126    False
# att127    False
# att128    False
# target    False
# Length: 129, dtype: bool

# %%
cbf.isna().sum()
# Out:
# att1      0
# att2      0
# att3      0
# att4      0
# att5      0
#          ..
# att125    0
# att126    0
# att127    0
# att128    0
# target    0
# Length: 129, dtype: int64

# %%
import seaborn as sns
sns.heatmap(cbf.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %% [markdown]
# ### Line Plot CBF dataset

# %%
from pandas import read_csv
from matplotlib import pyplot
cbf.plot()
pyplot.show()

# %% [markdown]
# ### Line plot with dots

# %%
from pandas import read_csv
from matplotlib import pyplot
cbf.plot(style='k.')
pyplot.show()

# %% [markdown]
# ### Histogram CBF dataset

# %%
from pandas import read_csv
from matplotlib import pyplot
cbf.hist(figsize=(12,12))
pyplot.show()

# %% [markdown]
# ### Density Plot CBF dataset

# %%
from pandas import read_csv
from matplotlib import pyplot
cbf.plot(kind='kde')
pyplot.show()
