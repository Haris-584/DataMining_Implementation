# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# Original

# %%
# !python gdrive/My\ Drive/Colab\ Notebooks/LSTM-FCN-master/fifty_words_model.py
# Out:
# Using TensorFlow backend.
# 2020-07-20 07:55:43.819376: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-07-20 07:55:46.749283: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-07-20 07:55:46.752945: E tensorflow/stream_executor/cuda/cuda_driver.cc:313] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-07-20 07:55:46.752991: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (7397c87bcb59): /proc/driver/nvidia/version does not exist
# 2020-07-20 07:55:46.758970: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2300000000 Hz
# 2020-07-20 07:55:46.759205: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2957640 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# ...

# %% [markdown]
# Batch 64 and with additional Cov

# %%
# !python gdrive/My\ Drive/Colab\ Notebooks/LSTM-FCN-master/fifty_words_model.py
# Out:
# Using TensorFlow backend.
# 2020-07-20 08:15:18.776262: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-07-20 08:15:21.595425: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-07-20 08:15:21.599085: E tensorflow/stream_executor/cuda/cuda_driver.cc:313] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-07-20 08:15:21.599134: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (7397c87bcb59): /proc/driver/nvidia/version does not exist
# 2020-07-20 08:15:21.605253: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2300000000 Hz
# 2020-07-20 08:15:21.605524: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2789640 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# ...

# %% [markdown]
# Batch 128 with additional Cov

# %%
# !python gdrive/My\ Drive/Colab\ Notebooks/LSTM-FCN-master/fifty_words_model.py
# Out:
# Using TensorFlow backend.
# 2020-07-20 08:32:55.441579: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-07-20 08:32:58.523302: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-07-20 08:32:58.527322: E tensorflow/stream_executor/cuda/cuda_driver.cc:313] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-07-20 08:32:58.527396: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (7397c87bcb59): /proc/driver/nvidia/version does not exist
# 2020-07-20 08:32:58.535109: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2300000000 Hz
# 2020-07-20 08:32:58.535418: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1dcd640 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# ...

# %% [markdown]
# Batch size 256 , epoch 110 , with conv

# %%
# !python gdrive/My\ Drive/Colab\ Notebooks/LSTM-FCN-master/fifty_words_model.py
# Out:
# Using TensorFlow backend.
# 2020-07-20 09:09:15.492980: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-07-20 09:09:18.248145: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-07-20 09:09:18.251811: E tensorflow/stream_executor/cuda/cuda_driver.cc:313] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-07-20 09:09:18.251854: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (7397c87bcb59): /proc/driver/nvidia/version does not exist
# 2020-07-20 09:09:18.257836: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2300000000 Hz
# 2020-07-20 09:09:18.258067: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x24d9640 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# ...

# %% [markdown]
# batch size 128 , epoch 2000 , dropout 0.5 , 3 layers

# %%
# !python gdrive/My\ Drive/Colab\ Notebooks/LSTM-FCN-master/fifty_words_model.py
# Out:
# Streaming output truncated to the last 5000 lines.
#  - 6s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 1.1840 - val_accuracy: 0.7341
#
# Epoch 00758: loss did not improve from 0.00188
# Epoch 759/2000
#  - 6s - loss: 0.0032 - accuracy: 1.0000 - val_loss: 1.0603 - val_accuracy: 0.7648
#
# Epoch 00759: loss did not improve from 0.00188
# Epoch 760/2000
#  - 7s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.0339 - val_accuracy: 0.7648
#
# Epoch 00760: loss did not improve from 0.00188
# Epoch 761/2000
#  - 7s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.0494 - val_accuracy: 0.7560
#
# Epoch 00761: loss did not improve from 0.00188
# Epoch 762/2000
#  - 7s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.0776 - val_accuracy: 0.7582
#
# Epoch 00762: loss did not improve from 0.00188
# Epoch 763/2000
#  - 7s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.0940 - val_accuracy: 0.7516
#
# Epoch 00763: loss did not improve from 0.00188
# Epoch 764/2000
# ...

# %% [markdown]
# Sigmoid

# %%
# !python gdrive/My\ Drive/Colab\ Notebooks/LSTM-FCN-master/fifty_words_model.py
# Out:
# Using TensorFlow backend.
# 2020-07-20 15:23:21.509597: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-07-20 15:23:24.043310: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-07-20 15:23:24.046872: E tensorflow/stream_executor/cuda/cuda_driver.cc:313] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-07-20 15:23:24.046918: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (be7a6c6578e4): /proc/driver/nvidia/version does not exist
# 2020-07-20 15:23:24.052876: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2200000000 Hz
# 2020-07-20 15:23:24.053112: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x26972c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# ...

# %%
# !python gdrive/My\ Drive/Colab\ Notebooks/LSTM-FCN-master/fifty_words_model.py
# Out:
# Using TensorFlow backend.
# 2020-07-20 15:37:00.607643: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-07-20 15:37:03.086656: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-07-20 15:37:03.090180: E tensorflow/stream_executor/cuda/cuda_driver.cc:313] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-07-20 15:37:03.090233: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (be7a6c6578e4): /proc/driver/nvidia/version does not exist
# 2020-07-20 15:37:03.096167: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2200000000 Hz
# 2020-07-20 15:37:03.096441: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x21b92c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# ...

# %%
# !python gdrive/My\ Drive/Colab\ Notebooks/LSTM-FCN-master/fifty_words_model.py
# Out:
# Using TensorFlow backend.
# 2020-07-21 02:39:15.137143: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-07-21 02:39:19.220097: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-07-21 02:39:19.281876: E tensorflow/stream_executor/cuda/cuda_driver.cc:313] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-07-21 02:39:19.281971: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (effe572dd385): /proc/driver/nvidia/version does not exist
# 2020-07-21 02:39:19.324350: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2300000000 Hz
# 2020-07-21 02:39:19.324647: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1e212c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# ...

# %% [markdown]
# 5 lyer

# %%
# !python gdrive/My\ Drive/Colab\ Notebooks/LSTM-FCN-master/fifty_words_model.py
# Out:
# Using TensorFlow backend.
# 2020-07-21 02:57:57.328982: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-07-21 02:58:00.062617: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-07-21 02:58:00.066167: E tensorflow/stream_executor/cuda/cuda_driver.cc:313] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-07-21 02:58:00.066221: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (effe572dd385): /proc/driver/nvidia/version does not exist
# 2020-07-21 02:58:00.073569: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2300000000 Hz
# 2020-07-21 02:58:00.073807: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x31a52c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# ...
